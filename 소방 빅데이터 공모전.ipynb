# %% [markdown]
# # 1. 데이터 로드 및 확인

# %%
import pandas as pd

data1 = pd.read_csv('data999.csv')
data1.head()
# Out:
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3267: DtypeWarning: Columns (9,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   acdnt_cause  year season_se_nm  qu_se_nm  hour daywk sigungu_nm emd_nm  \
# 0        안전조치  2011           겨울       1.0     2   토요일        제주시    조천읍
# 1          기타  2011           겨울       1.0     8   토요일       서귀포시    상효동
# 2      잠금장치개방  2011           겨울       1.0    12   토요일        제주시   오라이동
# 3        안전조치  2011           겨울       1.0    13   토요일        제주시    한림읍
# 4          기타  2011           겨울       1.0    14   토요일        제주시    노형동
#
#    cty_frmvl_se_nm dong_se  ...  time_unit_wd  time_unit_humidity  \
# 0                0       읍  ...         340.0                84.0
# 1                1       동  ...         320.0                74.0
# 2                1       동  ...         340.0                70.0
# 3                0       읍  ...         320.0                65.0
# 4                1       동  ...         360.0                69.0
#
#    time_unit_msnf frstt_nm ward_nm lfdau_nm  spt_arvl_dsp_diff  qu_se  \
# 0             3.5    동부소방서    조천센터      NaN               10.0    NaN
# 1             9.9   서귀포소방서  서귀포구조대      NaN               20.0    NaN
# 2             2.9    제주소방서   제주구조대      NaN               10.0    NaN
# 3             2.8    서부소방서   서부구조대      NaN                2.0    NaN
# 4             2.7    제주소방서    노형센터      NaN                2.0    NaN
#
#    emd_se_nm      y
# 0        NaN  10분이상
# 1        NaN  20분이상
# 2        NaN  10분이상
# 3        NaN   5분이하
# 4        NaN   5분이하
#
# [5 rows x 29 columns]

# %%
data1.columns
# Out:
# Index(['acdnt_cause', 'year', 'season_se_nm', 'qu_se_nm', 'hour', 'daywk',
#        'sigungu_nm', 'emd_nm', 'cty_frmvl_se_nm', 'dong_se', 'loc_info_x',
#        'loc_info_y', 'spt_frstt_dist', 'acdnt_place_nm',
#        'acdnt_place_detail_nm', 'acdnt_cause_asort_nm', 'time_unit_tmprt',
#        'time_unit_rainqty', 'time_unit_ws', 'time_unit_wd',
#        'time_unit_humidity', 'time_unit_msnf', 'frstt_nm', 'ward_nm',
#        'lfdau_nm', 'spt_arvl_dsp_diff', 'qu_se', 'emd_se_nm', 'y'],
#       dtype='object')

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299821 entries, 0 to 299820
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   acdnt_cause            299821 non-null  object
#  1   year                   299821 non-null  int64
#  2   season_se_nm           299821 non-null  object
#  3   qu_se_nm               75972 non-null   float64
#  4   hour                   299821 non-null  int64
#  5   daywk                  299821 non-null  object
#  6   sigungu_nm             299821 non-null  object
#  7   emd_nm                 299821 non-null  object
#  8   cty_frmvl_se_nm        299821 non-null  int64
#  9   dong_se                75972 non-null   object
#  10  loc_info_x             299821 non-null  float64
#  11  loc_info_y             299821 non-null  float64
#  12  spt_frstt_dist         299821 non-null  float64
#  13  acdnt_place_nm         299821 non-null  object
#  14  acdnt_place_detail_nm  299821 non-null  object
#  15  acdnt_cause_asort_nm   299821 non-null  object
#  16  time_unit_tmprt        299821 non-null  float64
#  17  time_unit_rainqty      34289 non-null   float64
#  18  time_unit_ws           299821 non-null  float64
#  19  time_unit_wd           299558 non-null  float64
#  20  time_unit_humidity     299821 non-null  float64
#  21  time_unit_msnf         4418 non-null    float64
#  22  frstt_nm               299821 non-null  object
#  23  ward_nm                299821 non-null  object
#  24  lfdau_nm               26510 non-null   object
#  25  spt_arvl_dsp_diff      299821 non-null  float64
#  26  qu_se                  223849 non-null  float64
#  27  emd_se_nm              223849 non-null  object
#  28  y                      299821 non-null  object
# dtypes: float64(12), int64(3), object(14)
# memory usage: 66.3+ MB

# %%
print(data1['sido_nm'].unique(),'\n')
print(data1['sido_nm'].nunique(), '\n')
print(data1['sido_nm'].value_counts())
# Out:
# ['제주특별자치도']
#
# 1
#
# 제주특별자치도    76165
# Name: sido_nm, dtype: int64

# %%
data2 = pd.read_csv('raw_data2.csv')
data2.head()
# Out:
#   msfrtn_resc_reprt_no acdnt_cause prcs_result_se_nm  dclr_ymd  dclr_tm  \
# 0    20114501201S00001        위치확인                기타  20110101     2800
# 1    20114501201S00002        위치확인                기타  20110101    24000
# 2    20114501201S00003          화재                기타  20110101    32600
# 3    20114501201S00004          교통                기타  20110101    51500
# 4    20114506103S00001          산악              인명구조  20110101    83100
#
#    dclr_yr season_se_nm  qu_se  dclr_mnth  dclr_day  ...  \
# 0     2011           겨울      1          1         1  ...
# 1     2011           겨울      1          1         1  ...
# 2     2011           겨울      1          1         1  ...
# 3     2011           겨울      1          1         1  ...
# 4     2011           겨울      1          1         1  ...
#
#    acdnt_cause_asort_nm  time_unit_tmprt time_unit_rainqty  time_unit_ws  \
# 0                  위치확인              NaN               NaN           NaN
# 1                  위치확인             -9.3               NaN           0.8
# 2                    실화            -10.1               NaN           1.0
# 3                   차대차            -11.1               NaN           0.9
# 4                  일반조난            -14.6               NaN           0.8
#
#    time_unit_wd  time_unit_humidity  time_unit_msnf  frstt_nm         ward_nm  \
# 0           NaN                 NaN             NaN   전주덕진소방서      전주덕진119구조대
# 1         340.0                85.0             5.8   전주덕진소방서      전주덕진119구조대
# 2         180.0                87.0             5.8   전주덕진소방서      전주덕진119구조대
# 3         140.0                87.0             5.8   전주덕진소방서      전주덕진119구조대
# 4         340.0                85.0             5.5     남원소방서  인월119안전센터_폐서예정
#
#    lfdau_nm
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#
# [5 rows x 61 columns]

# %%
#print(data1.isnull().sum())
#print(data2.isnull().sum())

# %%
data1.dropna(axis=0, subset=['loc_info_x', 'loc_info_y', 'time_unit_tmprt', 
                            'time_unit_ws', 'time_unit_humidity'], inplace=True)

data1.isnull().sum()
# Out:
# resc_reprt_no             0
# acdnt_cause               0
# prcs_result_se_nm         0
# dclr_ymd                  0
# dclr_tm                   0
#                       ...
# time_unit_humidity        0
# time_unit_msnf        75312
# frstt_nm                  0
# ward_nm                   0
# lfdau_nm              73738
# Length: 61, dtype: int64

# %%
data2.dropna(axis=0, subset=['loc_info_x', 'loc_info_y', 'time_unit_tmprt', 
                            'time_unit_ws', 'time_unit_humidity'], inplace=True)

data2.isnull().sum()
# Out:
# msfrtn_resc_reprt_no         0
# acdnt_cause                  0
# prcs_result_se_nm            0
# dclr_ymd                     0
# dclr_tm                      0
#                          ...
# time_unit_humidity           0
# time_unit_msnf          220091
# frstt_nm                     0
# ward_nm                      0
# lfdau_nm                199573
# Length: 61, dtype: int64

# %%
#data['time_unit_rainqty'].fillna(0, inplace=True)
#data['time_unit_msnf'].fillna(0, inplace=True)
#data['lfdau_nm'].fillna('', inplace=True)
#data.dropna(axis=0, subset=['time_unit_tmprt'], inplace=True)
#data.dropna(axis=0, subset=['time_unit_ws'], inplace=True)
#data.dropna(axis=0, subset=['time_unit_humidity'], inplace=True)
#data.dropna(axis=0, subset=['time_unit_rainqty'], inplace=True)
#data.drop(['time_unit_msnf', 'lfdau_nm'], axis=1, inplace=True)

# %% [markdown]
# * time_unit_tmprt(시간단위기온) >> 결측치가 있는건 삭제해야하지 않나
#
# * time_unit_rainqty(시간단위강수량), time_unit_msnf(시간단위적설량) >> 강수량, 적설량 값이 없으면 0으로 대체
#
# * time_unit_ws(시간단위풍속), time_unit_humidity(시간단위습도) >> 애매
#
# * lfdau_nm(소방지역대명) >> 소방지역대명 존재하면 더미값으로 부여

# %%
#print(data1['emd_nm'].unique(),'\n')
#print(data1['emd_nm'].nunique(), '\n')
#print(data1['emd_nm'].value_counts())

# %%
#print(data.sort_values('spt_arvl_dsp_diff'))

# %%
#data1.columns

# %%
data1.drop(['resc_reprt_no', 'prcs_result_se_nm', 'sido_nm', 
            'dclr_mm', 'dclr_dd', 'dclr_mi', 'dsp_yr', 'dsp_mm', 
            'dsp_dd', 'dsp_hh', 'dsp_mi', 'spt_arvl_yr', 'spt_arvl_mm', 
            'spt_arvl_dd', 'spt_arvl_hh','spt_arvl_mi','resc_cmptn_ymd', 
            'resc_cmptn_tm', 'resc_cmptn_yr','resc_cmptn_mm', 
            'resc_cmptn_dd', 'resc_cmptn_hh', 'resc_cmptn_mi', 'hmg_ymd', 
            'hmg_tm', 'hmg_yr', 'hmg_mm', 'hmg_dd', 'hmg_hh', 'hmg_mi'], axis=1, inplace=True)
data1.head()
# Out:
#   acdnt_cause  dclr_ymd  dclr_tm  dclr_yr season_se_nm  qu_se_nm  dclr_hh  \
# 0        안전조치  20110101    21000     2011           겨울         1        2
# 1          기타  20110101    80300     2011           겨울         1        8
# 2      잠금장치개방  20110101   122500     2011           겨울         1       12
# 3        안전조치  20110101   135200     2011           겨울         1       13
# 4          기타  20110101   144000     2011           겨울         1       14
#
#   daywk   dsp_ymd  dsp_tm  ...  acdnt_cause_asort_nm  time_unit_tmprt  \
# 0   토요일  20110101   21200  ...                안전조치기타              2.5
# 1   토요일  20110101   80500  ...                    기타              1.6
# 2   토요일  20110101  122500  ...                   문개방              2.0
# 3   토요일  20110101  135500  ...              시설물복구및철거              2.0
# 4   토요일  20110101  144200  ...                    기타              2.2
#
#   time_unit_rainqty time_unit_ws time_unit_wd time_unit_humidity  \
# 0               NaN          9.0        340.0               84.0
# 1               NaN          2.3        320.0               74.0
# 2               0.3          8.5        340.0               70.0
# 3               NaN          6.2        320.0               65.0
# 4               NaN          7.4        360.0               69.0
#
#    time_unit_msnf  frstt_nm  ward_nm lfdau_nm
# 0             3.5     동부소방서     조천센터      NaN
# 1             9.9    서귀포소방서   서귀포구조대      NaN
# 2             2.9     제주소방서    제주구조대      NaN
# 3             2.8     서부소방서    서부구조대      NaN
# 4             2.7     제주소방서     노형센터      NaN
#
# [5 rows x 31 columns]

# %%
#data2.columns

# %%
data2.drop(['msfrtn_resc_reprt_no', 'prcs_result_se_nm', 'sido_nm', 
            'dclr_mnth', 'dclr_day', 'dclr_min', 'dsp_yr', 'dsp_mnth', 
            'dsp_day', 'dsp_hour', 'dsp_min', 'spt_arvl_yr', 'spt_arvl_mnth', 
            'spt_arvl_day', 'spt_arvl_hour','spt_arvl_min','resc_cmptn_ymd', 
            'resc_cmptn_tm','resc_cmptn_yr', 'resc_cmptn_mnth', 'resc_cmptn_day', 
            'resc_cmptn_hour','resc_cmptn_min', 'hmg_ymd', 'hmg_tm', 'hmg_yr', 
            'hmg_mnth', 'hmg_day', 'hmg_hour', 'hmg_min'], axis=1, inplace=True)
data2.head()
# Out:
#   acdnt_cause  dclr_ymd  dclr_tm  dclr_yr season_se_nm  qu_se  dclr_hour  \
# 1        위치확인  20110101    24000     2011           겨울      1          2
# 2          화재  20110101    32600     2011           겨울      1          3
# 3          교통  20110101    51500     2011           겨울      1          5
# 4          산악  20110101    83100     2011           겨울      1          8
# 5        동물포획  20110101   104100     2011           겨울      1         10
#
#   daywk   dsp_ymd  dsp_tm  ...  acdnt_cause_asort_nm  time_unit_tmprt  \
# 1   토요일  20110101   24700  ...                  위치확인             -9.3
# 2   토요일  20110101   32600  ...                    실화            -10.1
# 3   토요일  20110101   51500  ...                   차대차            -11.1
# 4   토요일  20110101   83100  ...                  일반조난            -14.6
# 5   토요일  20110101  104300  ...                 포유류기타             -5.8
#
#   time_unit_rainqty time_unit_ws time_unit_wd time_unit_humidity  \
# 1               NaN          0.8        340.0               85.0
# 2               NaN          1.0        180.0               87.0
# 3               NaN          0.9        140.0               87.0
# 4               NaN          0.8        340.0               85.0
# 5               NaN          0.9        200.0               69.0
#
#    time_unit_msnf  frstt_nm         ward_nm lfdau_nm
# 1             5.8   전주덕진소방서      전주덕진119구조대      NaN
# 2             5.8   전주덕진소방서      전주덕진119구조대      NaN
# 3             5.8   전주덕진소방서      전주덕진119구조대      NaN
# 4             5.5     남원소방서  인월119안전센터_폐서예정      NaN
# 5             5.6     익산소방서        익산119구조대      NaN
#
# [5 rows x 31 columns]

# %%
data1.rename(columns={'dclr_yr':'year', 'dclr_hh':'hour', 
                      'cty_frmvl_se':'cty_frmvl_se_nm'}, inplace=True)
data2.rename(columns={'dclr_yr':'year', 'dclr_hour':'hour'}, inplace=True)

# %% [markdown]
# * emd_nm(읍면동명), cty_frmvl_se(도시농촌구분명), dong_se(읍면동구분명)
#
# => 상관관계 있을 수 있다고 생각
#
# * resc_reprt_no(재난구조보고서번호)
#
# => 모든 값이 유니크
#
# * sido_nm(시도명)
#
# => 모든 값이 '제주특별자치도'로 동일
#
# * loc_info_x(위치정보X), loc_info_y(위치정보y)
#
# => 좌표값?
#
# * 풍향

# %% [markdown]
# # 2. 데이터 전처리

# %%
def time_format(x):
    
    if len(x) == 6:
        return x
    elif len(x) == 5:
        return '0'+x
    elif len(x) == 4:
        return '00'+x
    elif len(x) == 3:
        return '000' + x
    elif len(x) == 2:
        return '0000' + x
    elif len(x) == 1:
        return '00000' + x

#data['dclr_ymd'] = data['dclr_ymd'].astype(str)
#data['dclr_tm'] = data['dclr_tm'].astype(str)
#data['dclr_tm'] = data['dclr_tm'].apply(time_format)

data1['dsp_ymd'] = data1['dsp_ymd'].astype(str)
data1['dsp_tm'] = data1['dsp_tm'].astype(str)
data1['dsp_tm'] = data1['dsp_tm'].apply(time_format)

data1['spt_arvl_ymd'] = data1['spt_arvl_ymd'].astype(str)
data1['spt_arvl_tm'] = data1['spt_arvl_tm'].astype(str)
data1['spt_arvl_tm'] = data1['spt_arvl_tm'].apply(time_format)

data2['dsp_ymd'] = data2['dsp_ymd'].astype(str)
data2['dsp_tm'] = data2['dsp_tm'].astype(str)
data2['dsp_tm'] = data2['dsp_tm'].apply(time_format)

data2['spt_arvl_ymd'] = data2['spt_arvl_ymd'].astype(str)
data2['spt_arvl_tm'] = data2['spt_arvl_tm'].astype(str)
data2['spt_arvl_tm'] = data2['spt_arvl_tm'].apply(time_format)

# %%
for i in data1.index:
    #data.at[i, 'dclr_time'] = data.at[i, 'dclr_ymd'] + ' ' + data.at[i, 'dclr_tm']
    data1.at[i, 'dsp_time'] = data1.at[i, 'dsp_ymd'] + ' ' + data1.at[i, 'dsp_tm']
    data1.at[i, 'spt_arvl_time'] = data1.at[i, 'spt_arvl_ymd'] + ' ' + data1.at[i, 'spt_arvl_tm']

# %%
for i in data2.index:
    #data.at[i, 'dclr_time'] = data.at[i, 'dclr_ymd'] + ' ' + data.at[i, 'dclr_tm']
    data2.at[i, 'dsp_time'] = data2.at[i, 'dsp_ymd'] + ' ' + data2.at[i, 'dsp_tm']
    data2.at[i, 'spt_arvl_time'] = data2.at[i, 'spt_arvl_ymd'] + ' ' + data2.at[i, 'spt_arvl_tm']

# %%
#data['dclr_time'] = pd.to_datetime(data['dclr_time'], format='%Y-%m-%d %H:%M:%S')
data1['dsp_time'] = pd.to_datetime(data1['dsp_time'], format='%Y-%m-%d %H:%M:%S')
data1['spt_arvl_time'] = pd.to_datetime(data1['spt_arvl_time'], format='%Y-%m-%d %H:%M:%S')

data2['dsp_time'] = pd.to_datetime(data2['dsp_time'], format='%Y-%m-%d %H:%M:%S')
data2['spt_arvl_time'] = pd.to_datetime(data2['spt_arvl_time'], format='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# to_datetime 은 format을 현명하게 부여하지 않고도 작업을 수행 할 수 있지만 변환 속도는 format을 지정할 때보 다 훨씬 느립니다.
#
# to_datetime 의 infer_datetime_format 옵션을 True 로 설정하여 format 문자열을 제공하지 않고 datetime 문자열의 형식을 유추 할 수있는 경우 변환을 더 빠른 모드로 전환 할 수 있습니다.
#
# 파싱 ​​속도를 5 ~ 6 배 높일 수 있습니다.

# %%
for i in data1.index:
    data1.at[i,'spt_arvl_dsp_diff'] = data1.at[i,'spt_arvl_time'] - data1.at[i, 'dsp_time']

# %%
for i in data2.index:
    data2.at[i,'spt_arvl_dsp_diff'] = data2.at[i,'spt_arvl_time'] - data2.at[i, 'dsp_time']

# %%
data = pd.concat([data1, data2])
data
# Out:
#        acdnt_cause  dclr_ymd  dclr_tm  year season_se_nm  qu_se_nm  hour  \
# 0             안전조치  20110101    21000  2011           겨울       1.0     2
# 1               기타  20110101    80300  2011           겨울       1.0     8
# 2           잠금장치개방  20110101   122500  2011           겨울       1.0    12
# 3             안전조치  20110101   135200  2011           겨울       1.0    13
# 4               기타  20110101   144000  2011           겨울       1.0    14
# ...            ...       ...      ...   ...          ...       ...   ...
# 285397          기타  20201231   204500  2020           겨울       NaN    20
# 285398        동물포획  20201231   213300  2020           겨울       NaN    21
# 285400          기타  20201231   224000  2020           겨울       NaN    22
# 285401      잠금장치개방  20201231   225000  2020           겨울       NaN    22
# 285402      잠금장치개방  20201231   231700  2020           겨울       NaN    23
#
#        daywk   dsp_ymd  dsp_tm  ... time_unit_humidity time_unit_msnf  \
# 0        토요일  20110101  021200  ...               84.0            3.5
# 1        토요일  20110101  080500  ...               74.0            9.9
# 2        토요일  20110101  122500  ...               70.0            2.9
# 3        토요일  20110101  135500  ...               65.0            2.8
# 4        토요일  20110101  144200  ...               69.0            2.7
# ...      ...       ...     ...  ...                ...            ...
# 285397   목요일  20201231  204700  ...               92.0            4.9
# 285398   목요일  20201231  213300  ...               91.0            3.3
# 285400   목요일  20201231  224200  ...               90.0            4.6
# 285401   목요일  20201231  225200  ...               90.0            4.6
# 285402   목요일  20201231  231900  ...               90.0            3.1
#
#        frstt_nm         ward_nm lfdau_nm            dsp_time  \
# 0         동부소방서            조천센터      NaN 2011-01-01 02:12:00
# 1        서귀포소방서          서귀포구조대      NaN 2011-01-01 08:05:00
# 2         제주소방서           제주구조대      NaN 2011-01-01 12:25:00
# 3         서부소방서           서부구조대      NaN 2011-01-01 13:55:00
# 4         제주소방서            노형센터      NaN 2011-01-01 14:42:00
# ...         ...             ...      ...                 ...
# 285397    군산소방서       금동119안전센터      NaN 2020-12-31 20:47:00
# 285398    익산소방서       공단119안전센터      NaN 2020-12-31 21:33:00
# 285400    군산소방서       금동119안전센터      NaN 2020-12-31 22:42:00
# 285401    군산소방서  소룡119안전센터_폐서예정      NaN 2020-12-31 22:52:00
# 285402  전주덕진소방서      전주덕진119구조대      NaN 2020-12-31 23:19:00
#
#              spt_arvl_time  spt_arvl_dsp_diff  qu_se emd_se_nm
# 0      2011-01-01 02:22:00    0 days 00:10:00    NaN       NaN
# 1      2011-01-01 08:25:00    0 days 00:20:00    NaN       NaN
# 2      2011-01-01 12:35:00    0 days 00:10:00    NaN       NaN
# 3      2011-01-01 13:57:00    0 days 00:02:00    NaN       NaN
# 4      2011-01-01 14:44:00    0 days 00:02:00    NaN       NaN
# ...                    ...                ...    ...       ...
# 285397 2020-12-31 20:53:00    0 days 00:06:00    4.0         동
# 285398 2020-12-31 21:37:00    0 days 00:04:00    4.0         동
# 285400 2020-12-31 22:49:00    0 days 00:07:00    4.0         동
# 285401 2020-12-31 23:05:00    0 days 00:13:00    4.0         동
# 285402 2020-12-31 23:23:00    0 days 00:04:00    4.0         동
#
# [299821 rows x 36 columns]

# %%
data['spt_arvl_dsp_diff'] = data['spt_arvl_dsp_diff'].dt.seconds
data['spt_arvl_dsp_diff'] = data['spt_arvl_dsp_diff']/60

# %%
data.drop(['dclr_ymd', 'dclr_tm', 'dsp_ymd', 'dsp_tm', 'spt_arvl_ymd', 'spt_arvl_tm', 'dsp_time', 'spt_arvl_time'], axis=1, inplace=True)

# %%
import numpy as np

class_mapping = {label:idx for idx, label in enumerate(np.unique(data1['cty_frmvl_se_nm']))}

data['cty_frmvl_se_nm'] = data['cty_frmvl_se_nm'].map(class_mapping)

# %%
data.loc[data['spt_arvl_dsp_diff'] >= 0, 'y'] = '5분이하'
data.loc[data['spt_arvl_dsp_diff'] >= 5, 'y'] = '5분이상'
data.loc[data['spt_arvl_dsp_diff'] >= 10, 'y'] = '10분이상'
data.loc[data['spt_arvl_dsp_diff'] >= 15, 'y'] = '15분이상'
data.loc[data['spt_arvl_dsp_diff'] >= 20, 'y'] = '20분이상'

# %%
data['y'].value_counts()
# Out:
# 5분이상     122236
# 5분이하      64648
# 10분이상     58481
# 20분이상     28400
# 15분이상     26056
# Name: y, dtype: int64

# %%
data.to_csv("data999.csv", index=False)

# %%
df = pd.read_csv('data999.csv')
df.head()
# Out:
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3267: DtypeWarning: Columns (9,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   acdnt_cause  year season_se_nm  qu_se_nm  hour daywk sigungu_nm emd_nm  \
# 0        안전조치  2011           겨울       1.0     2   토요일        제주시    조천읍
# 1          기타  2011           겨울       1.0     8   토요일       서귀포시    상효동
# 2      잠금장치개방  2011           겨울       1.0    12   토요일        제주시   오라이동
# 3        안전조치  2011           겨울       1.0    13   토요일        제주시    한림읍
# 4          기타  2011           겨울       1.0    14   토요일        제주시    노형동
#
#    cty_frmvl_se_nm dong_se  ...  time_unit_wd  time_unit_humidity  \
# 0                0       읍  ...         340.0                84.0
# 1                1       동  ...         320.0                74.0
# 2                1       동  ...         340.0                70.0
# 3                0       읍  ...         320.0                65.0
# 4                1       동  ...         360.0                69.0
#
#    time_unit_msnf frstt_nm ward_nm lfdau_nm  spt_arvl_dsp_diff  qu_se  \
# 0             3.5    동부소방서    조천센터      NaN               10.0    NaN
# 1             9.9   서귀포소방서  서귀포구조대      NaN               20.0    NaN
# 2             2.9    제주소방서   제주구조대      NaN               10.0    NaN
# 3             2.8    서부소방서   서부구조대      NaN                2.0    NaN
# 4             2.7    제주소방서    노형센터      NaN                2.0    NaN
#
#    emd_se_nm      y
# 0        NaN  10분이상
# 1        NaN  20분이상
# 2        NaN  10분이상
# 3        NaN   5분이하
# 4        NaN   5분이하
#
# [5 rows x 29 columns]

# %%
df.shape
# Out:
# (299821, 29)

# %%
df.columns
# Out:
# Index(['acdnt_cause', 'year', 'season_se_nm', 'qu_se_nm', 'hour', 'daywk',
#        'sigungu_nm', 'emd_nm', 'cty_frmvl_se_nm', 'dong_se', 'loc_info_x',
#        'loc_info_y', 'spt_frstt_dist', 'acdnt_place_nm',
#        'acdnt_place_detail_nm', 'acdnt_cause_asort_nm', 'time_unit_tmprt',
#        'time_unit_rainqty', 'time_unit_ws', 'time_unit_wd',
#        'time_unit_humidity', 'time_unit_msnf', 'frstt_nm', 'ward_nm',
#        'lfdau_nm', 'spt_arvl_dsp_diff', 'qu_se', 'emd_se_nm', 'y'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import scatterplotmatrix

cols = ['spt_frstt_dist', 'time_unit_tmprt', 'time_unit_rainqty', 'time_unit_msnf', 'time_unit_ws', 'time_unit_humidity', 'spt_arvl_dsp_diff']

scatterplotmatrix(data[cols].values, figsize=(20, 15), 
                  names=cols, alpha=0.5)
plt.tight_layout()
plt.show()

# %%
from mlxtend.plotting import heatmap

cm = np.corrcoef(data[cols].values.T)
hm = heatmap(cm, row_names=cols, column_names=cols)

plt.show()

# %%
data.head()
# Out:
#   acdnt_cause prcs_result_se_nm season_se_nm  qu_se_nm daywk emd_nm  \
# 0        안전조치              안전조치           겨울         1   토요일    조천읍
# 1          기타              인명구조           겨울         1   토요일    상효동
# 2      잠금장치개방              인명구조           겨울         1   토요일   오라이동
# 3        안전조치              안전조치           겨울         1   토요일    한림읍
# 4          기타              안전조치           겨울         1   토요일    노형동
#
#    cty_frmvl_se dong_se  spt_frstt_dist acdnt_place_nm  ...  \
# 0             0       읍             2.0          상가ㆍ시장  ...
# 1             1       동             9.0           단독주택  ...
# 2             1       동             6.0             빌라  ...
# 3             0       읍             1.0             기타  ...
# 4             1       동             2.0            아파트  ...
#
#   time_unit_humidity time_unit_msnf  frstt_nm  ward_nm  lfdau_nm  \
# 0               84.0            3.5     동부소방서     조천센터
# 1               74.0            9.9    서귀포소방서   서귀포구조대
# 2               70.0            2.9     제주소방서    제주구조대
# 3               65.0            2.8     서부소방서    서부구조대
# 4               69.0            2.7     제주소방서     노형센터
#
#     dsp_dclr_diff  spt_arvl_dsp_diff spt_arvl_dclr_diff  \
# 0 0 days 00:02:00               10.0    0 days 00:12:00
# 1 0 days 00:02:00               20.0    0 days 00:22:00
# 2 0 days 00:00:00               10.0    0 days 00:10:00
# 3 0 days 00:03:00                2.0    0 days 00:05:00
# 4 0 days 00:02:00                2.0    0 days 00:04:00
#
#   resc_cmptn_spt_arvl_diff hmg_time_resc_cmptn_diff
# 0          0 days 00:26:00          0 days 00:05:00
# 1          0 days 01:25:00          0 days 00:25:00
# 2          0 days 00:15:00          0 days 00:15:00
# 3          0 days 00:10:00          0 days 00:03:00
# 4          0 days 00:16:00          0 days 00:05:00
#
# [5 rows x 25 columns]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.9, test_size=0.1, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

mlr = LinearRegression()
mlr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = mlr.predict(X_test)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.scatter(y_test, y_predict, alpha=0.4)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("MULTIPLE LINEAR REGRESSION")
plt.show()

# %%
print(mlr.coef_)
# Out:
# [  0.11443117   1.27399902  -1.49296     -1.41456255   6.5350301
#   -1.17792063  -0.63935199  -0.47185228   1.20383332   2.19963784
#    0.3305845   13.53471701  -0.49300567  -0.64921574   0.30704309
#    1.8425043    5.51884534   7.01028149  -0.42252133   1.9975374
#    0.68196006   1.2287598   -0.16669168  -0.15732008  -0.14876876
#    3.61875984   1.99426183   0.43549253  -0.49095828  -0.2900108
#   -0.30432672  -0.7684375   -1.12047668  -8.36008065  -1.96329351
#    7.54467267  -3.19447581  -4.83806453   2.62685      5.56894291
#   -8.79635863  -1.34534031  -1.95552942  -6.28316325  -5.27096012
#    5.54295317  -3.01385013  -2.50957181  -0.92884555   0.98120295
#    0.13874096  -7.99620614  -7.98088622  -5.53434512  -6.8333123
#   -5.20369665   5.8207092    4.92782801   4.82913097  -2.9022719
#   -0.84356724  -1.18689403  -7.90244043  -2.32421615  -7.86897948
#   -6.52767659   4.09923585   1.00773999  -6.09260402   8.04984501
#   -4.56087453  -4.67116855  -7.06943285  -4.81563508  -8.46257788
#   -3.02462337  -2.41882809   1.24286057  -5.30226955  -6.32066771
#   -7.54183284  -4.12183796  -1.59198742  -9.61443422  -7.82563193
#   -3.61584168  -2.83338674  -7.16910509  -7.55872486   2.43349615
#    1.91662896  -8.34871477   0.63208488  -2.25351439   8.59826929
#    7.09910712  -1.37801048   0.35143462  -6.47480814   2.06005233
#    0.61393285  -5.87908028  -6.87936251   6.48190888   2.02207768
#  -13.19249062 -21.60228621 -13.20387421 -17.26696991 -19.51283811
#   -7.50501917 -21.09005878 -17.66703738 -15.79741893 -11.84359511
#  -15.62019219 -19.8662913   -9.86686641 -13.6623266  -16.13571951
#   -7.37465583 -10.77991742 -19.07153978 -13.35761886 -12.1385548
#  -18.04770366 -10.29064212 -14.54855503  -8.4220533   -9.64489767
#   -7.40124115  -3.86450486 -16.08482634 -20.55131728 -13.93270301
#  -16.67663435  -6.85504254  -9.9332944  -12.1160062  -16.49115598]

# %%
print(mlr.score(X_train, y_train))
# Out:
# 0.20351295810862458
